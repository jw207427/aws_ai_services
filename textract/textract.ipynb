# %%
import boto3
from IPython.display import Image, display
# from trp import Document
from PIL import Image as PImage, ImageDraw
import time
from IPython.display import IFrame

textract = boto3.client('textract')

# %% [markdown]
# ### 1. Detect text from scan

# %%
filename = 'handwriting.jpg'
display(Image(filename=filename))

# %%
# Read document content
with open(filename, 'rb') as document:
    imageBytes = bytearray(document.read())

# Call Amazon Textract
response = textract.detect_document_text(Document={'Bytes': imageBytes})

# Print detected text
for item in response["Blocks"]:
    print(item["BlockType"])
#     if item["BlockType"] == "Line":
#         print (item["Text"])
# Out:
# PAGE
# LINE
# LINE
# LINE
# LINE
# LINE
# LINE
# LINE
# LINE
# LINE
# LINE
# LINE
# LINE
# LINE
# LINE
# LINE
# LINE
# LINE
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD
# WORD

# %% [markdown]
# ### Lines and Words of Text - Json Structure

# %%
print("JSON Response\n===================")
display(response)
# Out:
# JSON Response
# ...
# {'DocumentMetadata': {'Pages': 1},
#  'Blocks': [{'BlockType': 'PAGE',
#    'Geometry': {'BoundingBox': {'Width': 0.9994903206825256,
#      'Height': 1.0,
#      'Left': 0.0,
#      'Top': 0.0},
#     'Polygon': [{'X': 0.0, 'Y': 0.0},
#      {'X': 0.9994903206825256, 'Y': 3.0491838789373086e-16},
#      {'X': 0.9994903206825256, 'Y': 1.0},
#      {'X': 0.0, 'Y': 1.0}]},
#    'Id': '9318162c-e221-4e75-a4ff-ed7f34b62af7',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['43df7371-f799-4579-85e8-914430481267',
#       '70d6fbff-e9c9-4fc2-9029-34703e04c0f5',
#       '52a7f04f-443e-4b18-a144-950e489293b2',
#       '235bdfcb-2be2-48ee-b8ff-4a8cf68643d9',
#       '3501d1da-611b-451c-9867-d8811be781ce',
#       '7f0a0b0c-6910-444a-9d43-04e00c86a397',
#       '6b288d9d-36aa-4ce4-a0c8-9ddf80b1478d',
#       'f629a316-a3b7-4f9d-8daf-ae88ce40dd7b',
#       '4442b649-bce9-46e3-859c-9785809ece98',
#       'e5e98b2a-a3ef-45ac-8b6e-b51a8fb3d82e',
# ...

# %%
import pprint as pp
# Call Amazon Textract
response = textract.analyze_document(Document={'Bytes': imageBytes}, FeatureTypes=["FORMS"])

print("JSON Response\n===================")
# display(response)

for b in response['Blocks']:
#     pp.pprint(b["BlockType"])
    if b['BlockType']=='LINE':#'KEY_VALUE_SET':
        pp.pprint(b)
#     if b['TextType']=='HANDWRITING':
#         pp.pprint(b)
# Out:
# JSON Response
# ...
# {'BlockType': 'LINE',
#  'Confidence': 99.57870483398438,
#  'Geometry': {'BoundingBox': {'Height': 0.045285120606422424,
#                               'Left': 0.014406505040824413,
#                               'Top': 0.04122166335582733,
#                               'Width': 0.12558498978614807},
#               'Polygon': [{'X': 0.014406505040824413, 'Y': 0.04122166335582733},
#                           {'X': 0.13999150693416595, 'Y': 0.04122166335582733},
#                           {'X': 0.13999150693416595, 'Y': 0.08650678396224976},
#                           {'X': 0.014406505040824413,
#                            'Y': 0.08650678396224976}]},
#  'Id': '717b7968-3d82-4c2c-8496-cea0d6a3e89e',
#  'Relationships': [{'Ids': ['aa77fa75-33d7-4510-87be-58e11d784e34',
#                             '81066e5a-8bfa-4481-bf4b-549bd75f3c62'],
#                     'Type': 'CHILD'}],
#  'Text': "Applicant's name"}
# {'BlockType': 'LINE',
# ...
